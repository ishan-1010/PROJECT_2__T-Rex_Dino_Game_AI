# %%
import numpy as np
from PIL import ImageGrab #grabbing image
from PIL import Image
import cv2 #opencv
import io
import time
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (30, 30)
import seaborn as sns
import pandas as pd
import numpy as np
from random import randint
import os
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

from selenium.webdriver.chrome.service import Service

from selenium.webdriver.common.keys import Keys
#keras imports
# %matplotlib inline 
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
import json

# %%
from selenium.webdriver.common.by import By


class Game:
    def __init__(self,custom_config=True):
        service = Service(r"C:\Users\Ishan\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("disable-infobars")
        self._driver = webdriver.Chrome(service=service, options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.set_window_size(200, 300)
        self._driver.get(os.path.abspath(r"game/dino.html"))
        #modifying game before trainNetworkining
        if custom_config:
            self._driver.execute_script("Runner.config.ACCELERATION=0")
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
        
        time.sleep(0.25)# no actions are possible 
                        # for 0.25 sec after game starts, 
                        # skip learning at this time and make the model wait
    def press_up(self):
        self._driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game):
        self._game = game;
        self.jump();
        time.sleep(.5)
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
#processing image as required
def process_img(image):
    #game is already in grey scale canvas, canny to get only edges and reduce unwanted objects(clouds)
#     image = cv2.Canny(image, threshold1 = 100, threshold2 = 200)
#     image = image[10:140,0:200] #img[y:y+h, x:x+w]
#     image = resized_image = cv2.resize(image, (80, 80)) 
    image = cv2.resize(image, (0,0), fx = 0.15, fy = 0.10)
    image = image[2:38,10:50] #img[y:y+h, x:x+w]
    image = cv2.Canny(image, threshold1 = 100, threshold2 = 200)
    return  image

# %%
def grab_screen(_driver = None):
    screen =  np.array(ImageGrab.grab(bbox=(40,180,440,400)))
    image = process_img(screen)
    if _driver!=None:
        image = _driver.get_screenshot_as_png()
    return image

# %%
import pickle
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.8 # decay rate of past observations original 0.99
OBSERVATION = 20000. # timesteps to observe before training
EXPLORE = 50000 #300000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4

# %%
# """initial variable caching, done only once"""
# save_obj(INITIAL_EPSILON,"epsilon")
# t = 0
# save_obj(t,"time")
# D = deque()
# save_obj(D,"D")

# %%
img_rows , img_cols = 40,20
img_channels = 4 #We stack 4 frames

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
#     Conv2D(32, (8, 8), strides=(4, 4), input_shape=(20, 40, 4..., padding="same")`
    model.add(Conv2D(32, (8, 8), strides=(4, 4), padding='same',input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4), strides=(2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    print("We finish building the model")
    return model

# %%
def trainNetwork(model,game_state,observe=False):
    # open up a game state to communicate with emulator
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #deque()
    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 
    x_t, r_0, terminal = game_state.get_state(do_nothing)
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    

    #In Keras, need to reshape
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4
    initial_state = s_t

    if observe :#args['mode'] == 'Run':
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon")#FINAL_EPSILON #INITIAL_EPSILON
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time")
    while (True):
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0
        a_t = np.zeros([ACTIONS])
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0:
            if  random.random() <= epsilon:
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else:
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)
                action_index = max_Q
                a_t[action_index] = 1
        #We reduced the epsilon gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE #update to original asap

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('loop took {} seconds'.format(time.time()-last_time))
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3)
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: # and terminal: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]
                state_t1 = minibatch[i][3]
                terminal = minibatch[i][4]
                # if terminated, only equals reward

                inputs[i:i + 1] = state_t    #I saved down s_t

                targets[i] = model.predict(state_t)  # Hitting each buttom probability
                Q_sa = model.predict(state_t1)
                
                if terminal:
                    targets[i, action_t] = reward_t
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)
            # targets2 = normalize(targets)
            loss = model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
        else:
#             artificial time delay as training done with this delay
#             loss_df.loc[len(loss_df)] = 0
            time.sleep(0.15)
        s_t = initial_state if terminal else s_t1
        t = t + 1
        
        # save progress every 10000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            clear_output()
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
loss_df = pd.read_csv("./objects/loss_df.csv")
scores_df = pd.read_csv("./objects/scores_df.csv")
actions_df = pd.read_csv("./objects/actions_df.csv")
q_max_df = pd.read_csv("./objects/q_values.csv")

# %%
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)
    model = buildmodel()
    trainNetwork(model,game_state,observe=observe)

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img()
        self._display.__next__()
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1]
        reward = 0.1
        is_over = False
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen()
        self._display.send(image)

        if self._agent.is_crashed():
            score = self._game.get_score()
            scores_df.loc[len(loss_df)] = score
            self._game.restart()
            reward = -11/score
            is_over = True
        return image, reward, is_over

# %%
from keras.models import model_from_json
from keras.models import Sequential
from keras.src.layers.core import Dense, Dropout, Activation, Flatten
from keras.src.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
import tensorflow as tf
from keras.callbacks import TensorBoard
from collections import deque
import random
import json

# %%
def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
#         cv2.imwrite("screenshot"+str(frame)+".png",screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#searchforplay
playGame(observe=False)
# Out:
# Now we build the model
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# We finish building the model
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 1/1 [==============================] - 0s 228ms/step
# loop took 0.8257462978363037 seconds
# TIMESTEP 1 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.5290303230285645 seconds
# TIMESTEP 2 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.4073302745819092 seconds
# TIMESTEP 3 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.458873987197876 seconds
# TIMESTEP 4 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 60ms/step
# loop took 0.5106632709503174 seconds
# TIMESTEP 5 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.4537043571472168 seconds
# TIMESTEP 6 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.4504430294036865 seconds
# TIMESTEP 7 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.48839759826660156 seconds
# TIMESTEP 8 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 109ms/step
# loop took 0.8467097282409668 seconds
# TIMESTEP 9 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 201ms/step
# loop took 1.1756112575531006 seconds
# TIMESTEP 10 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 103ms/step
# loop took 0.6878974437713623 seconds
# TIMESTEP 11 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.46685361862182617 seconds
# TIMESTEP 12 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 66ms/step
# loop took 0.472015380859375 seconds
# TIMESTEP 13 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.34470295906066895 seconds
# TIMESTEP 14 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.4420905113220215 seconds
# TIMESTEP 15 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2547438144683838 seconds
# TIMESTEP 16 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.43883585929870605 seconds
# TIMESTEP 17 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.42644667625427246 seconds
# TIMESTEP 18 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.43402528762817383 seconds
# TIMESTEP 19 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 35ms/step
# loop took 0.42497992515563965 seconds
# TIMESTEP 20 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.48641085624694824 seconds
# TIMESTEP 21 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.45061302185058594 seconds
# TIMESTEP 22 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.4604198932647705 seconds
# TIMESTEP 23 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 34ms/step
# loop took 0.4221045970916748 seconds
# TIMESTEP 24 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.41216087341308594 seconds
# TIMESTEP 25 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.45118212699890137 seconds
# TIMESTEP 26 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.448209285736084 seconds
# TIMESTEP 27 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.46622300148010254 seconds
# TIMESTEP 28 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.3406698703765869 seconds
# TIMESTEP 29 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 54ms/step
# loop took 0.5074279308319092 seconds
# TIMESTEP 30 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 58ms/step
# loop took 0.6005914211273193 seconds
# TIMESTEP 31 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 74ms/step
# loop took 0.6231932640075684 seconds
# TIMESTEP 32 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.30068516731262207 seconds
# TIMESTEP 33 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 78ms/step
# loop took 0.7248260974884033 seconds
# TIMESTEP 34 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 78ms/step
# loop took 0.5494165420532227 seconds
# TIMESTEP 35 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 73ms/step
# loop took 0.5045478343963623 seconds
# TIMESTEP 36 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.3461930751800537 seconds
# TIMESTEP 37 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 68ms/step
# loop took 0.5514540672302246 seconds
# TIMESTEP 38 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.49797821044921875 seconds
# TIMESTEP 39 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.5117111206054688 seconds
# TIMESTEP 40 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 56ms/step
# loop took 0.49454498291015625 seconds
# TIMESTEP 41 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.516333818435669 seconds
# TIMESTEP 42 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 58ms/step
# loop took 0.5196669101715088 seconds
# TIMESTEP 43 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 82ms/step
# loop took 0.5325696468353271 seconds
# TIMESTEP 44 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.6228673458099365 seconds
# TIMESTEP 45 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.5789473684210527 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.48006176948547363 seconds
# TIMESTEP 46 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.4546506404876709 seconds
# TIMESTEP 47 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2713747024536133 seconds
# TIMESTEP 48 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2722818851470947 seconds
# TIMESTEP 49 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.4363853931427002 seconds
# TIMESTEP 50 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.4575014114379883 seconds
# TIMESTEP 51 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.44319987297058105 seconds
# TIMESTEP 52 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.47197461128234863 seconds
# TIMESTEP 53 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.49095726013183594 seconds
# TIMESTEP 54 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.5507071018218994 seconds
# TIMESTEP 55 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.720689058303833 seconds
# TIMESTEP 56 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2558139534883721 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.46835827827453613 seconds
# TIMESTEP 57 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.4828319549560547 seconds
# TIMESTEP 58 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.4581310749053955 seconds
# TIMESTEP 59 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.45587635040283203 seconds
# TIMESTEP 60 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.5472712516784668 seconds
# TIMESTEP 61 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.46359944343566895 seconds
# TIMESTEP 62 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5023820400238037 seconds
# TIMESTEP 63 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.47809934616088867 seconds
# TIMESTEP 64 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.7365033626556396 seconds
# TIMESTEP 65 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2894736842105263 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.46898484230041504 seconds
# TIMESTEP 66 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 35ms/step
# loop took 0.4546377658843994 seconds
# TIMESTEP 67 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.4747128486633301 seconds
# TIMESTEP 68 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.4680824279785156 seconds
# TIMESTEP 69 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 35ms/step
# loop took 0.444199800491333 seconds
# TIMESTEP 70 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.47312402725219727 seconds
# TIMESTEP 71 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.39019012451171875 seconds
# TIMESTEP 72 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.4778177738189697 seconds
# TIMESTEP 73 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.7478876113891602 seconds
# TIMESTEP 74 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.4983804225921631 seconds
# TIMESTEP 75 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.48752307891845703 seconds
# TIMESTEP 76 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.45200562477111816 seconds
# TIMESTEP 77 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.4452650547027588 seconds
# TIMESTEP 78 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5345573425292969 seconds
# TIMESTEP 79 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.4736177921295166 seconds
# TIMESTEP 80 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.44472813606262207 seconds
# TIMESTEP 81 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0
/ STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.21153846153846154 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.49776387214660645 seconds
# TIMESTEP 193 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 53ms/step
# loop took 0.4508545398712158 seconds
# TIMESTEP 194 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.5346012115478516 seconds
# TIMESTEP 195 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 40ms/step
# loop took 0.4119710922241211 seconds
# TIMESTEP 196 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 54ms/step
# loop took 0.46999669075012207 seconds
# TIMESTEP 197 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.6974267959594727 seconds
# TIMESTEP 198 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.4864528179168701 seconds
# TIMESTEP 199 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.7187156677246094 seconds
# TIMESTEP 200 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.3497343063354492 seconds
# TIMESTEP 201 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 56ms/step
# loop took 0.4307394027709961 seconds
# TIMESTEP 202 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 69ms/step
# loop took 0.5650441646575928 seconds
# TIMESTEP 203 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.38611602783203125 seconds
# TIMESTEP 204 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 55ms/step
# loop took 0.5547442436218262 seconds
# TIMESTEP 205 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5069711208343506 seconds
# TIMESTEP 206 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 86ms/step
# loop took 0.5717728137969971 seconds
# TIMESTEP 207 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 62ms/step
# loop took 0.8562049865722656 seconds
# TIMESTEP 208 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.5242965221405029 seconds
# TIMESTEP 209 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 52ms/step
# loop took 0.3984830379486084 seconds
# TIMESTEP 210 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.5338466167449951 seconds
# TIMESTEP 211 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.39160776138305664 seconds
# TIMESTEP 212 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 63ms/step
# loop took 0.5118968486785889 seconds
# TIMESTEP 213 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 63ms/step
# loop took 0.5101418495178223 seconds
# TIMESTEP 214 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.45413661003112793 seconds
# TIMESTEP 215 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 52ms/step
# loop took 0.5178532600402832 seconds
# TIMESTEP 216 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.734022855758667 seconds
# TIMESTEP 217 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2894736842105263 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 54ms/step
# loop took 0.545342206954956 seconds
# TIMESTEP 218 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.3871920108795166 seconds
# TIMESTEP 219 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.5189673900604248 seconds
# TIMESTEP 220 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.29923081398010254 seconds
# TIMESTEP 221 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 57ms/step
# loop took 0.4663829803466797 seconds
# TIMESTEP 222 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2994861602783203 seconds
# TIMESTEP 223 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 66ms/step
# loop took 0.5878100395202637 seconds
# TIMESTEP 224 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.4673426151275635 seconds
# TIMESTEP 225 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 40ms/step
# loop took 0.6582489013671875 seconds
# TIMESTEP 226 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -0.2894736842105263 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.26680779457092285 seconds
# TIMESTEP 227 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.44860243797302246 seconds
# TIMESTEP 228 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.4565918445587158 seconds
# TIMESTEP 229 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.44240427017211914 seconds
# TIMESTEP 230 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.45780062675476074 seconds
# TIMESTEP 231 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 34ms/step
# loop took 0.4404728412628174 seconds
# TIMESTEP 232 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.3480057716369629 seconds
# TIMESTEP 233 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.4541816711425781 seconds
# TIMESTEP 234 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.3481936454772949 seconds
# TIMESTEP 235 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.7081496715545654 seconds
# TIMESTEP 236 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.460482120513916 seconds
# TIMESTEP 237 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 55ms/step
# loop took 0.4995594024658203 seconds
# TIMESTEP 238 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.4690275192260742 seconds
# TIMESTEP 239 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.37685728073120117 seconds
# TIMESTEP 240 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.4720911979675293 seconds
# TIMESTEP 241 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.4653453826904297 seconds
# TIMESTEP 242 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.4645054340362549 seconds
# TIMESTEP 243 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.4524569511413574 seconds
# TIMESTEP 244 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.775956392288208 seconds
# TIMESTEP 245 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2894736842105263 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.4881904125213623 seconds
# TIMESTEP 246 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.46660804748535156 seconds
# TIMESTEP 247 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.42316436767578125 seconds
# TIMESTEP 248 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 59ms/step
# loop took 0.5308952331542969 seconds
# TIMESTEP 249 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.44409728050231934 seconds
# TIMESTEP 250 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 108ms/step
# loop took 0.8322958946228027 seconds
# TIMESTEP 251 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 65ms/step
# loop took 0.54827880859375 seconds
# TIMESTEP 252 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.7013249397277832 seconds
# TIMESTEP 253 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 51ms/step
# loop took 0.5374593734741211 seconds
# TIMESTEP 254 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 58ms/step
# loop took 0.5081419944763184 seconds
# TIMESTEP 255 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 66ms/step
# loop took 0.5364048480987549 seconds
# TIMESTEP 256 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.48524904251098633 seconds
# TIMESTEP 257 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.479783296585083 seconds
# TIMESTEP 258 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 40ms/step
# loop took 0.4558846950531006 seconds
# TIMESTEP 259 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.365903377532959 seconds
# TIMESTEP 260 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.36796045303344727 seconds
# TIMESTEP 261 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.758061408996582 seconds
# TIMESTEP 262 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2894736842105263 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.5112738609313965 seconds
# TIMESTEP 263 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 52ms/step
# loop took 0.4916095733642578 seconds
# TIMESTEP 264 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5049774646759033 seconds
# TIMESTEP 265 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2984890937805176 seconds
# TIMESTEP 266 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.4863417148590088 seconds
# TIMESTEP 267 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 58ms/step
# loop took 0.6307597160339355 seconds
# TIMESTEP 268 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 64ms/step
# loop took 0.5235707759857178 seconds
# TIMESTEP 269 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.5037024021148682 seconds
# TIMESTEP 270 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ...
# TIMESTEP 800 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.4599771499633789 seconds
# TIMESTEP 801 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.47460007667541504 seconds
# TIMESTEP 802 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.26363301277160645 seconds
# TIMESTEP 803 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.39319372177124023 seconds
# TIMESTEP 804 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.37972307205200195 seconds
# TIMESTEP 805 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.4223601818084717 seconds
# TIMESTEP 806 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.37436413764953613 seconds
# TIMESTEP 807 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 54ms/step
# loop took 0.43749141693115234 seconds
# TIMESTEP 808 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.4416983127593994 seconds
# TIMESTEP 809 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.45952296257019043 seconds
# TIMESTEP 810 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 36ms/step
# loop took 0.5160024166107178 seconds
# TIMESTEP 811 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 35ms/step
# loop took 0.43834757804870605 seconds
# TIMESTEP 812 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.43354034423828125 seconds
# TIMESTEP 813 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.35289812088012695 seconds
# TIMESTEP 814 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.3726227283477783 seconds
# TIMESTEP 815 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 29ms/step
# loop took 0.7094683647155762 seconds
# TIMESTEP 816 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.23404255319148937 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 66ms/step
# loop took 0.47793054580688477 seconds
# TIMESTEP 817 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5485010147094727 seconds
# TIMESTEP 818 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.4285705089569092 seconds
# TIMESTEP 819 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 47ms/step
# loop took 0.4941847324371338 seconds
# TIMESTEP 820 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.48639559745788574 seconds
# TIMESTEP 821 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.5063278675079346 seconds
# TIMESTEP 822 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.45082616806030273 seconds
# TIMESTEP 823 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.46978235244750977 seconds
# TIMESTEP 824 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.8003671169281006 seconds
# TIMESTEP 825 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.5210144519805908 seconds
# TIMESTEP 826 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 52ms/step
# loop took 0.46657657623291016 seconds
# TIMESTEP 827 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.47951292991638184 seconds
# TIMESTEP 828 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2580857276916504 seconds
# TIMESTEP 829 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.45214152336120605 seconds
# TIMESTEP 830 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.4544365406036377 seconds
# TIMESTEP 831 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.5321371555328369 seconds
# TIMESTEP 832 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.4755270481109619 seconds
# TIMESTEP 833 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.7556538581848145 seconds
# TIMESTEP 834 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 49ms/step
# loop took 0.5052759647369385 seconds
# TIMESTEP 835 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.48325085639953613 seconds
# TIMESTEP 836 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.4743483066558838 seconds
# TIMESTEP 837 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.4774198532104492 seconds
# TIMESTEP 838 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.5395350456237793 seconds
# TIMESTEP 839 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.40981507301330566 seconds
# TIMESTEP 840 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.2872905731201172 seconds
# TIMESTEP 841 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 37ms/step
# loop took 0.4958162307739258 seconds
# TIMESTEP 842 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.4889838695526123 seconds
# TIMESTEP 843 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.4551985263824463 seconds
# TIMESTEP 844 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 45ms/step
# loop took 0.4440734386444092 seconds
# TIMESTEP 845 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.5523538589477539 seconds
# TIMESTEP 846 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.48650121688842773 seconds
# TIMESTEP 847 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.47645092010498047 seconds
# TIMESTEP 848 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 54ms/step
# loop took 0.46945714950561523 seconds
# TIMESTEP 849 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 38ms/step
# loop took 0.3817169666290283 seconds
# TIMESTEP 850 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 39ms/step
# loop took 0.6644718647003174 seconds
# TIMESTEP 851 / STATE observe / EPSILON 0.1 / ACTION 0 / REWARD -0.1527777777777778 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# loop took 0.390378475189209 seconds
# TIMESTEP 852 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.5313863754272461 seconds
# TIMESTEP 853 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.4684162139892578 seconds
# TIMESTEP 854 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.46947813034057617 seconds
# TIMESTEP 855 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 44ms/step
# loop took 0.44915056228637695 seconds
# TIMESTEP 856 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 50ms/step
# loop took 0.4673299789428711 seconds
# TIMESTEP 857 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 41ms/step
# loop took 0.47840142250061035 seconds
# TIMESTEP 858 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 46ms/step
# loop took 0.47301793098449707 seconds
# TIMESTEP 859 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 34ms/step
# loop took 0.8034682273864746 seconds
# TIMESTEP 860 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD -0.2972972972972973 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 42ms/step
# loop took 0.46647214889526367 seconds
# TIMESTEP 861 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 48ms/step
# loop took 0.4941830635070801 seconds
# TIMESTEP 862 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 40ms/step
# loop took 0.47977614402770996 seconds
# TIMESTEP 863 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 40ms/step
# loop took 0.47700047492980957 seconds
# TIMESTEP 864 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.504340410232544 seconds
# TIMESTEP 865 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# 1/1 [==============================] - 0s 43ms/step
# loop took 0.45169734954833984 seconds
# TIMESTEP 866 / STATE observe / EPSILON 0.1 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18556\3053897582.py in <module>
#       1 #searchforplay
# ----> 2 playGame(observe=False)
#
# ~\AppData\Local\Temp\ipykernel_18556\3347678668.py in playGame(observe)
#       4     game_state = Game_sate(dino,game)
#       5     model = buildmodel()
# ----> 6     trainNetwork(model,game_state,observe=observe)
#
# ~\AppData\Local\Temp\ipykernel_18556\781485956.py in trainNetwork(model, game_state, observe)
#      56
#      57         #run the selected action and observed next state and reward
# ---> 58         x_t1, r_t, terminal = game_state.get_state(a_t)
#      59         print('loop took {} seconds'.format(time.time()-last_time))
#      60         last_time = time.time()
#
# ~\AppData\Local\Temp\ipykernel_18556\956217076.py in get_state(self, actions)
#      14         self._display.send(image)
#      15
# ---> 16         if self._agent.is_crashed():
#      17             score = self._game.get_score()
#      18             scores_df.loc[len(loss_df)] = score
#
# ~\AppData\Local\Temp\ipykernel_18556\3482963026.py in is_crashed(self)
#       7         return self._game.get_playing()
#       8     def is_crashed(self):
# ----> 9         return self._game.get_crashed()
#      10     def jump(self):
#      11         self._game.press_up()
#
# ~\AppData\Local\Temp\ipykernel_18556\3990115557.py in get_crashed(self)
#      29             self._driver.execute_script("Runner.config.ACCELERATION=0")
#      30     def get_crashed(self):
# ---> 31         return self._driver.execute_script("return Runner.instance_.crashed")
#      32     def get_playing(self):
#      33         return self._driver.execute_script("return Runner.instance_.playing")
#
# c:\Users\Ishan\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     402         command = Command.W3C_EXECUTE_SCRIPT
#     403
# --> 404         return self.execute(command, {"script": script, "args": converted_args})["value"]
#     405
#     406     def execute_async_script(self, script: str, *args):
#
# c:\Users\Ishan\anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# --> 344             self.error_handler.check_response(response)
#     345             response["value"] = self._unwrap_value(response.get("value", None))
#     346             return response
#
# c:\Users\Ishan\anaconda\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=117.0.5938.92)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6D25A7892+54818]
# 	(No symbol) [0x00007FF6D2516AC2]
# 	(No symbol) [0x00007FF6D23CDA3B]
# 	(No symbol) [0x00007FF6D23ADEE8]
# 	(No symbol) [0x00007FF6D2433237]
# 	(No symbol) [0x00007FF6D2446C6F]
# 	(No symbol) [0x00007FF6D242E883]
# 	(No symbol) [0x00007FF6D2403691]
# 	(No symbol) [0x00007FF6D24048D4]
# 	GetHandleVerifier [0x00007FF6D290B992+3610402]
# 	GetHandleVerifier [0x00007FF6D2961860+3962352]
# 	GetHandleVerifier [0x00007FF6D2959D4F+3930847]
# 	GetHandleVerifier [0x00007FF6D2643646+693206]
# 	(No symbol) [0x00007FF6D2521628]
# 	(No symbol) [0x00007FF6D251D934]
# 	(No symbol) [0x00007FF6D251DA62]
# 	(No symbol) [0x00007FF6D250E113]
# 	BaseThreadInitThunk [0x00007FFDFE5B257D+29]
# 	RtlUserThreadStart [0x00007FFDFF4CAA78+40]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def show_plots(realtime = True,t=0):
    fig, axs = plt.subplots(ncols=2,nrows =2)
    loss_df = pd.read_csv("./objects/loss_df.csv")
    scores_df = pd.read_csv("./objects/scores_df.csv")
    actions_df = pd.read_csv("./objects/actions_df.csv")
    q_max_df = pd.read_csv("./objects/q_values.csv")
    loss_df['loss'] = loss_df['loss'].astype('float') 
    loss_df.plot(use_index=True,ax=axs[0,0])
    scores_df.plot(ax=axs[0,1])
    sns.distplot(actions_df.tail(20000),ax=axs[1,0])
#     q_max_df.plot(ax = axs[1,1])
    imgg = fig.canvas.draw()
    graph_img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
    graph_img = graph_img.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#     disp = show_img(graphs=True)
#     disp.__next__()
    cv2.imwrite("logs/progress/pg"+str(t)+".png",graph_img) if realtime else 0

# %%
show_plots(realtime=False)
# Out:
# c:\Users\Ishan\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Ishan\AppData\Local\Temp\ipykernel_17884\1500985606.py:13: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   graph_img = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')

# %%
scores_df.tail(1000).plot()
# Out:
# <AxesSubplot:>
